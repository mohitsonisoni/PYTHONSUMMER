# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#now reading data from csv files
df=pd.read_csv('com.csv')

# %%
#printing data fro dataframes
df
# Out:
#             Name Department      Manager  Salary
# 0     Robin Hood        NaN          NaN     200
# 1  Arsene Wenger        Bar   Friar Tuck      50
# 2     Friar Tuck        Foo   Robin Hood     100
# 3    Little John        Foo   Robin Hood     100
# 4  Sam Allardyce        NaN          NaN     250
# 5  Dimi Berbatov        Foo  Little John      50

# %%
#top two lines print
df.head(2)
# Out:
#             Name Department     Manager  Salary
# 0     Robin Hood        NaN         NaN     200
# 1  Arsene Wenger        Bar  Friar Tuck      50

# %%
#exlore df
dir(df)
# Out:
# ['Department',
#  'Manager',
#  'Name',
#  'Salary',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
#for  single olumn
df['Salary'],df['Name']
# Out:
# (0    200
#  1     50
#  2    100
#  3    100
#  4    250
#  5     50
#  Name: Salary, dtype: int64, 0       Robin Hood
#  1    Arsene Wenger
#  2       Friar Tuck
#  3      Little John
#  4    Sam Allardyce
#  5    Dimi Berbatov
#  Name: Name, dtype: object)

# %%
#one way of extracting columns
df.iloc[0].values
# Out:
# array(['Robin Hood', nan, nan, 200], dtype=object)

# %%
#for 0 to 1 rows
#here .values will remove header and index rows
df.iloc[0:3]
# Out:
#             Name Department     Manager  Salary
# 0     Robin Hood        NaN         NaN     200
# 1  Arsene Wenger        Bar  Friar Tuck      50
# 2     Friar Tuck        Foo  Robin Hood     100

# %%
#all rows and selected columns
df.iloc[0:,0:3]
# Out:
#             Name Department      Manager
# 0     Robin Hood        NaN          NaN
# 1  Arsene Wenger        Bar   Friar Tuck
# 2     Friar Tuck        Foo   Robin Hood
# 3    Little John        Foo   Robin Hood
# 4  Sam Allardyce        NaN          NaN
# 5  Dimi Berbatov        Foo  Little John

# %%
#only looking for last column
df.iloc[:,-1]
# Out:
# 0    200
# 1     50
# 2    100
# 3    100
# 4    250
# 5     50
# Name: Salary, dtype: int64

# %%
l_column=df.iloc[:,-1]

# %%
l_column
# Out:
# 0    200
# 1     50
# 2    100
# 3    100
# 4    250
# 5     50
# Name: Salary, dtype: int64

# %%
l_column.max()
# Out:
# 250

# %%
l_column.min()
# Out:
# 50

# %%
l_column.mean()
# Out:
# 125.0

# %%
#any random columns
ab=df[['Name','Salary']]

# %%
#pploting graph with pandas
df.plot(kind='bar',x='Name',y='Salary',color='red')
