# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
 from PIL import Image

# %%
pic=Image.open('index.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x177 at 0x1FA3918B240>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr=np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (177, 284, 3)

# %%
plt.imshow(pic_arr) #it will show the image in graph which as an array

# %%
pic_red=pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape #nothing will change
# Out:
# (177, 284, 3)

# %%
plt.imshow(pic_red [:,:,0],cmap='gray') #this will show the gray with Red color

# %%
plt.imshow(pic_red [:,:,1],cmap='gray') #this will show the image in gray filter with green colour

# %%
plt.imshow(pic_red [:,:,2],cmap='gray') #this will show the image in gray filter with the blue color

# %%
#pic_red[:,:,1] =0 #this line remove the green color presense and makes the combinations of blue and red 
#pic_red[:,:,0] =0  #this line remove the red color presense and makes the combinations of blue and green 
pic_red[:,:,2] =0 #this line remove the green color presense and makes the combinations of green and red

# %%
plt.imshow(pic_red)
